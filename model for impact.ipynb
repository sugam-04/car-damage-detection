# %%
# from google.colab import drive

# # Mount Google Drive to /content/drive
# drive.mount('/content/drive')

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, BatchNormalization, Dropout
from tensorflow.keras.applications import VGG16
from tensorflow.keras.optimizers import Adam

# Set the seed for reproducibility
tf.random.set_seed(42)

# Define the path to your dataset
train_data_dir = 'C:/Users/user/OneDrive/Desktop/Sugam Car Detection ML/data3a/training'
validation_data_dir = 'C:/Users/user/OneDrive/Desktop/Sugam Car Detection ML/data3a/validation'

# Define image size and channels
img_width, img_height = 150, 150
channels = 3  # RGB

# Define the input shape based on your images
input_shape = (img_width, img_height, channels)

# Define the number of classes
num_classes = 3  # front, rear, side

# Define hyperparameters
epochs = 75
batch_size = 32

# Load the VGG16 model with pre-trained weights on ImageNet
base_model = VGG16(weights='imagenet', include_top=False, input_shape=input_shape)

# Freeze the pre-trained layers
# Unfreeze some layers for fine-tuning
# Unfreeze some layers for fine-tuning
for layer in base_model.layers:
    layer.trainable = False



# Create a Sequential model and add the VGG16 base model
model = Sequential()
model.add(base_model)

# Flatten the output of the VGG16 base model
model.add(Flatten())

# Add Dense layers with BatchNormalization and Dropout
model.add(Dense(256, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.3))
model.add(Dense(128, activation='relu'))
model.add(BatchNormalization())


# Output layer
model.add(Dense(num_classes, activation='softmax'))

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

# Display the model summary
model.summary()

# Create data generators to augment and normalize the data
train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255,
    shear_range=0.5,
    zoom_range=0.15,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    fill_mode="nearest",
    brightness_range=[0.2, 1.0],  # Adjust brightness
    channel_shift_range=30.0  # Adjust channel intensity
)


test_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical'
)

validation_generator = test_datagen.flow_from_directory(
    validation_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical'
)
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)

# Train the model with early stopping
model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // batch_size,
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // batch_size,
    callbacks=[early_stopping]
)
# Save the model
model.save('car_damage_impact_model_vgg.h5')
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 4, 4, 512)         14714688
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dense (Dense)               (None, 256)               2097408
#
#  batch_normalization (BatchN  (None, 256)              1024
#  ormalization)
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  batch_normalization_1 (Batc  (None, 128)              512
#  hNormalization)
#
#  dense_2 (Dense)             (None, 3)                 387
#
# =================================================================
# Total params: 16,846,915
# Trainable params: 2,131,459
# Non-trainable params: 14,715,456
# _________________________________________________________________
# Found 979 images belonging to 3 classes.
# Found 171 images belonging to 3 classes.
# Epoch 1/75
# 30/30 [==============================] - 285s 9s/step - loss: 1.2719 - accuracy: 0.4826 - val_loss: 2.7990 - val_accuracy: 0.4062
# Epoch 2/75
# 30/30 [==============================] - 249s 8s/step - loss: 0.9708 - accuracy: 0.5681 - val_loss: 1.8022 - val_accuracy: 0.3812
# Epoch 3/75
# 30/30 [==============================] - 278s 9s/step - loss: 0.9353 - accuracy: 0.5818 - val_loss: 1.6923 - val_accuracy: 0.3812
# Epoch 4/75
# 30/30 [==============================] - 223s 7s/step - loss: 0.8612 - accuracy: 0.6082 - val_loss: 1.0149 - val_accuracy: 0.6125
# Epoch 5/75
# 30/30 [==============================] - 250s 8s/step - loss: 0.8605 - accuracy: 0.6177 - val_loss: 1.2535 - val_accuracy: 0.5000
# Epoch 6/75
# 30/30 [==============================] - 222s 7s/step - loss: 0.8202 - accuracy: 0.6399 - val_loss: 0.8374 - val_accuracy: 0.5875
# Epoch 7/75
# 30/30 [==============================] - 216s 7s/step - loss: 0.7997 - accuracy: 0.6473 - val_loss: 0.8343 - val_accuracy: 0.6812
# Epoch 8/75
# 30/30 [==============================] - 222s 7s/step - loss: 0.8067 - accuracy: 0.6346 - val_loss: 1.5849 - val_accuracy: 0.5375
# Epoch 9/75
# 30/30 [==============================] - 221s 7s/step - loss: 0.7937 - accuracy: 0.6484 - val_loss: 1.0876 - val_accuracy: 0.5500
# Epoch 10/75
# 30/30 [==============================] - 221s 7s/step - loss: 0.7536 - accuracy: 0.6515 - val_loss: 1.0405 - val_accuracy: 0.6000
# Epoch 11/75
# 30/30 [==============================] - 221s 7s/step - loss: 0.7660 - accuracy: 0.6621 - val_loss: 0.8422 - val_accuracy: 0.6250
# Epoch 12/75
# 30/30 [==============================] - 214s 7s/step - loss: 0.7272 - accuracy: 0.6758 - val_loss: 0.8523 - val_accuracy: 0.6375
# Epoch 13/75
# 30/30 [==============================] - 216s 7s/step - loss: 0.7395 - accuracy: 0.6779 - val_loss: 0.8758 - val_accuracy: 0.6562
# Epoch 14/75
# 30/30 [==============================] - 230s 8s/step - loss: 0.7109 - accuracy: 0.6895 - val_loss: 4.1124 - val_accuracy: 0.3313
# Epoch 15/75
# 30/30 [==============================] - 223s 7s/step - loss: 0.7512 - accuracy: 0.6705 - val_loss: 0.8663 - val_accuracy: 0.6438
# Epoch 16/75
# 30/30 [==============================] - 218s 7s/step - loss: 0.7406 - accuracy: 0.6737 - val_loss: 0.8165 - val_accuracy: 0.7063
# Epoch 17/75
# 30/30 [==============================] - 224s 8s/step - loss: 0.7241 - accuracy: 0.6727 - val_loss: 0.8401 - val_accuracy: 0.6250
# Epoch 18/75
# 30/30 [==============================] - 226s 8s/step - loss: 0.7185 - accuracy: 0.6864 - val_loss: 0.8463 - val_accuracy: 0.6500
# Epoch 19/75
# 30/30 [==============================] - 220s 7s/step - loss: 0.7232 - accuracy: 0.6822 - val_loss: 1.2334 - val_accuracy: 0.5562
# Epoch 20/75
# 30/30 [==============================] - 214s 7s/step - loss: 0.7051 - accuracy: 0.6980 - val_loss: 0.8648 - val_accuracy: 0.6250
# Epoch 21/75
# 30/30 [==============================] - 216s 7s/step - loss: 0.6819 - accuracy: 0.7001 - val_loss: 0.8431 - val_accuracy: 0.6500
# Epoch 22/75
# 30/30 [==============================] - 217s 7s/step - loss: 0.6607 - accuracy: 0.7128 - val_loss: 0.8540 - val_accuracy: 0.6375
# Epoch 23/75
# 30/30 [==============================] - 221s 7s/step - loss: 0.6676 - accuracy: 0.7043 - val_loss: 0.8311 - val_accuracy: 0.6375
# Epoch 24/75
# 30/30 [==============================] - 223s 7s/step - loss: 0.6781 - accuracy: 0.7096 - val_loss: 0.8018 - val_accuracy: 0.7188
# Epoch 25/75
# 30/30 [==============================] - 213s 7s/step - loss: 0.6700 - accuracy: 0.7181 - val_loss: 0.8228 - val_accuracy: 0.6875
# Epoch 26/75
# 30/30 [==============================] - 219s 7s/step - loss: 0.6479 - accuracy: 0.7212 - val_loss: 0.8784 - val_accuracy: 0.6500
# Epoch 27/75
# 30/30 [==============================] - 224s 8s/step - loss: 0.6587 - accuracy: 0.7096 - val_loss: 0.8490 - val_accuracy: 0.6438
# Epoch 28/75
# 30/30 [==============================] - 219s 7s/step - loss: 0.6303 - accuracy: 0.7455 - val_loss: 0.9598 - val_accuracy: 0.6062
# Epoch 29/75
# 30/30 [==============================] - 253s 9s/step - loss: 0.6753 - accuracy: 0.7075 - val_loss: 0.9684 - val_accuracy: 0.5500
# Epoch 30/75
# 30/30 [==============================] - 246s 8s/step - loss: 0.6539 - accuracy: 0.7307 - val_loss: 1.0409 - val_accuracy: 0.5500
# Epoch 31/75
# 30/30 [==============================] - 260s 9s/step - loss: 0.6125 - accuracy: 0.7244 - val_loss: 0.8249 - val_accuracy: 0.6313
# Epoch 32/75
# 30/30 [==============================] - 301s 10s/step - loss: 0.6176 - accuracy: 0.7265 - val_loss: 1.8229 - val_accuracy: 0.4812
# Epoch 33/75
# 30/30 [==============================] - 231s 8s/step - loss: 0.6060 - accuracy: 0.7392 - val_loss: 0.9458 - val_accuracy: 0.5750
# Epoch 34/75
# 30/30 [==============================] - 232s 8s/step - loss: 0.6107 - accuracy: 0.7181 - val_loss: 0.8687 - val_accuracy: 0.6625
# Epoch 35/75
# 30/30 [==============================] - 233s 8s/step - loss: 0.5974 - accuracy: 0.7286 - val_loss: 0.9958 - val_accuracy: 0.6313
# Epoch 36/75
# 30/30 [==============================] - 223s 7s/step - loss: 0.6496 - accuracy: 0.6927 - val_loss: 0.8801 - val_accuracy: 0.6375
# Epoch 37/75
# 30/30 [==============================] - 232s 8s/step - loss: 0.5570 - accuracy: 0.7571 - val_loss: 0.9031 - val_accuracy: 0.6375
# Epoch 38/75
# 30/30 [==============================] - 235s 8s/step - loss: 0.6465 - accuracy: 0.7286 - val_loss: 0.8967 - val_accuracy: 0.6313
# Epoch 39/75
# 30/30 [==============================] - 232s 8s/step - loss: 0.6456 - accuracy: 0.7202 - val_loss: 0.9877 - val_accuracy: 0.6625

# %%
# Evaluate the model on the validation set
validation_loss, validation_accuracy = model.evaluate(validation_generator, steps=validation_generator.samples // batch_size)
print(f"Validation Accuracy: {validation_accuracy * 100:.2f}%")

# Make predictions on new images
from tensorflow.keras.preprocessing import image
import numpy as np

def predict_image(model, img_path):
    img = image.load_img(img_path, target_size=(img_width, img_height))

    # Convert the image to an array
    img_array = image.img_to_array(img)

    # Expand the dimensions to match the model's expected input shape
    img_array = np.expand_dims(img_array, axis=0)

    # Rescale the image to match the training data preprocessing
    img_array /= 255.0

    # Make predictions
    prediction = model.predict(img_array)

    # Get the predicted class index
    predicted_class = np.argmax(prediction)

    # Get class labels from the generator
    classes = list(train_generator.class_indices.keys())

    # Get the class name corresponding to the predicted index
    class_name = classes[predicted_class]

    return class_name, prediction[0]
# Evaluate the model on the validation set
validation_loss, validation_accuracy = model.evaluate(validation_generator)
print(f"Overall Validation Accuracy: {validation_accuracy * 100:.2f}%")

# Replace 'path/to/new_image.jpg' with the path to your new image
new_image_path = 'C:/Users/user/OneDrive/Desktop/Sugam Car Detection ML/data2a/validation/01-rear/0030.JPEG'
predicted_class, prediction = predict_image(model, new_image_path)

print(f"Predicted Class: {predicted_class}")
print(f"Prediction Probabilities: {prediction}")

# You can also convert the probabilities to percentage
prediction_percentage = [f"{prob * 100:.2f}%" for prob in prediction]
print(f"Prediction Probabilities (Percentage): {prediction_percentage}")
# Out:
# 5/5 [==============================] - 34s 7s/step - loss: 0.8237 - accuracy: 0.7125
# Validation Accuracy: 71.25%
# 6/6 [==============================] - 37s 6s/step - loss: 0.8036 - accuracy: 0.7193
# Overall Validation Accuracy: 71.93%
# 1/1 [==============================] - 1s 878ms/step
# Predicted Class: 02-moderate
# Prediction Probabilities: [0.02454676 0.8547141  0.12073904]
# Prediction Probabilities (Percentage): ['2.45%', '85.47%', '12.07%']
